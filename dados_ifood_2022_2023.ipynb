# %% [markdown]
# <a href="https://colab.research.google.com/github/Julianajjss/Julianajjss/blob/main/dados_ifood_2022_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %% [markdown]
# **Variáveis e funções para todo o notebook**

# %%
month = {
    1:'January',
		2:'February',
		3:'March',
		4:'April',
		5:'May',
		6:'June',
		7:'July',
		8:'August',
		9:'September',
		10:'October',
		11:'November',
		12:'December'
}

# %%
def get_part_of_day(x):
    if (x > 4) and (x <= 8):
        return 'Early Morning'
    elif (x > 8) and (x <= 12 ):
        return 'Morning'
    elif (x > 12) and (x <= 16):
        return'Noon'
    elif (x > 16) and (x <= 20) :
        return 'Evening'
    elif (x > 20) and (x <= 24):
        return'Night'
    elif (x <= 4):
        return'Late Night'

# %%
def clean_title(text):
  if len(text.split(':')) <= 3:
    return ' '.join(text.split(':')[:1])
  else:
    return ' '.join(text.split(':')[:2])

# %%
ifood = pd.read_csv('/content/pedidos.csv')
ifood.head()
# Out:
#                              id_usuario  id_pedido  \
# 0  8d850551-d989-46be-b034-bb68f7c7eb3f       9323
# 1  8d850551-d989-46be-b034-bb68f7c7eb3f       5403
# 2  8d850551-d989-46be-b034-bb68f7c7eb3f       5732
# 3  8d850551-d989-46be-b034-bb68f7c7eb3f       4691
# 4  8d850551-d989-46be-b034-bb68f7c7eb3f       7763
#
#                       restaurante  valor     status data_registro data_pedido
# 0                    Doce Império   1.15  CONCLUDED    2021-09-13  2023-09-19
# 1                    Lu Do Pastel  25.96  CONCLUDED    2021-09-13  2023-09-09
# 2  Duquesa Confeitaria E Pizzaria  22.89  CONCLUDED    2021-09-13  2023-08-31
# 3          Subway - Vila Da Penha  35.90  CONCLUDED    2021-09-13  2023-08-27
# 4  Vila Do Sorvete - Vista Alegre  17.12  CONCLUDED    2021-09-13  2023-08-23

# %%
df = ifood['restaurante'].value_counts()

# %%
plt.figure(figsize=(25, 6))  # Tamanho da figura (opcional)
df.plot(kind='bar')
plt.title('Contagem de Restaurantes no iFood')
plt.xlabel('Restaurante')
plt.ylabel('Contagem')
plt.xticks(rotation=60)  # Rotaciona os rótulos no eixo x para facilitar a leitura (opcional)
plt.show()

# %%
ifood['valor'].sum()
# Out:
# 3360.7799999999997

# %%
ifood_end['cidade'].value_counts()
# Out:
# RIO DE JANEIRO             9
# JABOATÃO DOS GUARARAPES    6
# SÃO PAULO                  5
# BELO HORIZONTE             5
# FORTALEZA                  4
# MARICÁ                     1
# SÃO PEDRO DA ALDEIA        1
# RECIFE                     1
# Name: cidade, dtype: int64
